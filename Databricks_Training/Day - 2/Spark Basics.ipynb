# %% [markdown]
# #Spark
# - parallel processing
# #Datastructures in Spark
# - RDD
# - DF
# - DS
# - Currently data frame has all the capabilities of the RDD and DS

# %%
spark

# %%
data=([(1,'a'),(2,'b'),(3,'c')])
schema="id int, name string"
df=spark.createDataFrame(data,schema)

# %%
df.display()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df.display()

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df.display()

# %%
pandas_df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [2., 3., 4.],
    'c': ['string1', 'string2', 'string3'],
    'd': [date(2000, 1, 1), date(2000, 2, 1), date(2000, 3, 1)],
    'e': [datetime(2000, 1, 1, 12, 0), datetime(2000, 1, 2, 12, 0), datetime(2000, 1, 3, 12, 0)]
})
df = spark.createDataFrame(pandas_df)
df.display()

# %% [markdown]
# #Reader API

# %% [markdown]
# https://spark.apache.org/docs/latest/api/python/reference/index.html

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)

# %%
df_sales.display()

# %%
df_sales.write.saveAsTable("acc_dev.bhanu.sales_py")

# %%
# %sql
select * from acc_dev.bhanu.sales_py

# %%
df_sales=spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)
df_sales.write.mode("overwrite").saveAsTable("acc_dev.bhanu.sales_py")

# %%
(spark
 .read
 .csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)
 .write
 .mode("overwrite")
 .saveAsTable("acc_dev.bhanu.sales_py"))

# %%
# %sql
select * from acc_dev.bhanu.sales_py

# %%
df_HousePricing=spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")
df_HousePricing.write.mode("overwrite").saveAsTable("acc_dev.bhanu.house_price_py") #truncate and load
df_HousePricing.write.mode("append").saveAsTable("acc_dev.bhanu.house_price_py") #incremental data

# %%
df_HousePricing.display()

# %%
# %sql
select count(1) from acc_dev.bhanu.house_price_py

# %% [markdown]
# #Reading and Writing Json

# %%
df_retailorder=spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")
df_retailorder.write.mode("overwrite").saveAsTable("acc_dev.bhanu.retailorder_py")

# %%
# %sql
select * from acc_dev.bhanu.retailorder_py
--drop table if exists acc_dev.bhanu.retailorder_py

# %%
#df_finances=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv")
df_finances=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)
#df_finances.write.mode("overwrite").saveAsTable("acc_dev.bhanu.finances_py")

# %%
df_finances.display()

# %%
df_finances.select("customerID")

# %%
df1=df_finances.filter("CustomerID='CUST0044'")

# %%
df1.display()

# %%
from pyspark.sql.functions import col,current_timestamp,upper

# %%
df_finances.select(col("CustomerID").alias("cust_id")).display()

# %%
df_finances.withColumnRenamed("CustomerID","cust_id").withColumnRenamed("TransactionID","transaction_id").display()

# %%
df1=df_finances.withColumnsRenamed({"CustomerID":"cust_id","TransactionID":"transaction_id"})
df1.display()

# %%
df_finances.withColumn("ingestion_date",current_timestamp()).display()
df_finances.withColumn("Branch",upper("Branch")).display()
