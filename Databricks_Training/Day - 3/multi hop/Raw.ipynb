# %%
# %sql
select * from acc_dev.bhanu.sales

# %%
# %sql
delete from genai.default.docs_text

# %%
# %sql
grant usage on schema acc_dev.bhanu to `deepakvavilikolanu@gmail.com`;

# %%
# %sql
create table acc_dev.deepak_gold.customers as select * from acc_dev.bhanu.sales
    
c

# %%
# %sql
select * from naval_gold.agg
