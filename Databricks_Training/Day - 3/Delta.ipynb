-- %%
%sql
use catalog acc_dev;
CREATE SCHEMA IF NOT EXISTS bhanu;

-- %%
%sql
create table if not exists acc_dev.bhanu.employ(id int, name string,city string)

-- %%
%sql
insert into acc_dev.bhanu.employ values("1","bhanu","Hyderabad")

-- %%
%sql
describe extended employ

-- %%
%sql
desc detail employ

-- %%
%sql
desc history acc_dev.bhanu.employ

-- %%
%sql
insert into employ values("4","Ravi","Hyderabad")

-- %%
%sql
delete from employ where id ="3"

-- %%
%sql
select * from acc_dev.bhanu.employ version as of 4

-- %%
delete from acc_dev.bhanu.employ

-- %%
%sql
insert into acc_dev.naval.emp values("21","Bhanu","Hyd")

-- %%
restore table acc_dev.bhanu.employ version as of 4

-- %%
select * from acc_dev.bhanu.employ

-- %%
create table acc_dev.bhanu.Ice(id int,name string) using iceberg

-- %%
desc extended acc_dev.bhanu.Ice
