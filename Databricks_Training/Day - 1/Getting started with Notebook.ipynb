# %% [markdown]
# # Databricks NoteBook

# %%
print('hello')

# %%
# %sql
SELECT 'Run SQL'

# %% [markdown]
# ##Data Objects
#
# - Catalog
# - Schema
# - tables,views,volumes,functions

# %% [markdown]
# ![](/Volumes/acc_dev/bhanu/raw/object-model.png)

# %%
# %sql
use catalog acc_dev;
create schema if not exists Bhanu

# %%
# %sql
create table acc_dev.bhanu.demo(id int primary key)
